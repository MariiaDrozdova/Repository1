# %%
import os
import cv2 as cv2
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

from ds9_cmap import *

# %%
def openAsImage(fname):        
    fits_image = fits.open(fname)
    #print(fits_image.info())
    return fits_image[0].data

# %%
def produceImages(names):
    for fname in names:
        im = openAsImage(fname)
        
        try:
            #im = np.log(im+1)
            plt.imshow((im))#.astype(np.uint16))
            print(fname)
            plt.show()
        except AttributeError:
            pass
            print(fname)
            print("Cannot produce an image due to AttributeError")
        except TypeError:
            pass
            print(fname)
            print("Cannot produce an image due to TypeError")

# %%
def increase_brightness(img, value=30):
      
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)
    plt.imshow((hsv))#.astype(np.uint16))
    plt.show()

    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

# %%
def produceImageModelMap(name, cmap_name = 'brg'):
    im = openAsImage(name)
    im = im.astype(np.float32)
    #im = cv2.cvtColor(im, cv2.COLOR_GRAY2BGR)
    #im = increase_brightness(im, 0)
    try:
        #im = im * 1./np.max(im)
        print()
        im = np.log(im)
        plt.imshow((im), cmap=cmap_name)#.astype(np.uint16))
        print(name)
        plt.show()
    except:
        print("Error occured, cannot show an image")

# %%
cmaps = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar']

# %%
names = []
for i in os.listdir():
    if (i[-5:] == ".fits"):
        names.append(i)
#os.getcwd()

# %%
for i in cmaps:
    produceImageModelMap("sky1_model_map.fits", i)
# Out:
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits
# sky1_model_map.fits

# %%
for i in cmaps:
    produceImageModelMap("sky1_deconvolved_map.fits", i)
# Out:
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
# sky1_deconvolved_map.fits
